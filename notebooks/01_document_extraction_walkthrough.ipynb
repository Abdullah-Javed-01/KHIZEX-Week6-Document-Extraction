# %% [markdown]
# # Khizex Week 6 — Automated Document Extraction (OCR + NLP)
# This notebook is a compact walkthrough. The reusable implementation lives in `../src/pipeline.py`; evaluation outputs are in `../results/`.

# %% [raw]
# from pathlib import Path
# import sys, pandas as pd
# sys.path.insert(0, str(Path('..').resolve()))
# from src.pipeline import preprocess_image, ocr_image, extract_fields, extractive_summary, field_aware_summary

# %% [raw]
# scan = Path('../data/scans/contract_01.png')
# processed = preprocess_image(scan)
# text, confidence = ocr_image(processed)
# fields, sections = extract_fields(text)
# print('OCR confidence:', round(confidence,2))
# print(fields)
# print(field_aware_summary(fields))

# %% [markdown]
# ## Evaluation
# The full run evaluates OCR CER/WER field-level precision/recall/F1, summary ROUGE-L/completeness/hallucination, throughput, and failure modes. See `../results/metrics_summary.json` and the CSV files.

# %%
pd.read_csv('../results/extraction_metrics.csv')
